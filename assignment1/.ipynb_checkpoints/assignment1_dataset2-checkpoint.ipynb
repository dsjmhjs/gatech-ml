# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn_evaluation import plot
import loadData
import pandas as pd
import numpy as np
from sklearn import tree
import graphviz
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.tree._tree import TREE_LEAF
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedShuffleSplit
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import classification_report
from sklearn.utils import resample
# Out:
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# load data
training_set, testing_set = loadData.loadDataWithoutTestSet('processed.cleveland.data', split_to_test=True)
# get features and labels
training_set_labels = training_set.iloc[:,-1]
training_set = training_set.iloc[:,0:-1]

training_set_labels.reset_index(drop=True, inplace=True)
training_set.reset_index(drop=True, inplace=True)

testing_set_labels = testing_set.iloc[:,-1]
testing_set = testing_set.iloc[:,0:-1]

testing_set_labels.reset_index(drop=True, inplace=True)
testing_set.reset_index(drop=True, inplace=True)

print(training_set.shape)
print(testing_set.shape)

training_set.replace('?',0, inplace=True)
testing_set.replace('?',0, inplace=True)

training_set[['ca','thal']] = training_set[['ca','thal']].apply(pd.to_numeric)
testing_set[['ca','thal']] = testing_set[['ca','thal']].apply(pd.to_numeric)
# Out:
# (242, 13)
# (61, 13)

# %%
plt.bar(['0','1', '2', '3', '4'],[len(training_set_labels[training_set_labels==0]), 
         len(training_set_labels[training_set_labels==1]), 
             len(training_set_labels[training_set_labels==2]),
                len(training_set_labels[training_set_labels==3]),
                   len(training_set_labels[training_set_labels==4])])
plt.title('Training Set Label Distribution')
plt.savefig('dataset2_training_set_label_dist.png')
plt.show()
                 
plt.bar(['0','1', '2', '3', '4'],[len(testing_set_labels[testing_set_labels==0]), 
         len(testing_set_labels[testing_set_labels==1]), 
             len(testing_set_labels[testing_set_labels==2]),
                len(testing_set_labels[testing_set_labels==3]),
                   len(testing_set_labels[testing_set_labels==4])])
plt.title('Testing Set Label Distribution')
plt.savefig('dataset2_testing_set_label_dist.png')
plt.show()

# %%
# decision tree
dtc = tree.DecisionTreeClassifier()
dtc = dtc.fit(training_set, training_set_labels)

predicted_training_set_labels = dtc.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = dtc.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# 1.0
# 0.47540983606557374

# %%
criterion = ['gini', 'entropy']
splitter  = ['best','random']
min_samples_split = [2, 3, 4]
min_samples_leaf = [1, 2, 3, 4, 5]
param_grid = dict(criterion = criterion, splitter = splitter, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
grid_dtc = GridSearchCV(estimator=dtc, param_grid=param_grid)
grid_result_dtc = grid_dtc.fit(training_set, training_set_labels)


print("Best: %f using %s" % (grid_result_dtc.best_score_, grid_result_dtc.best_params_))
means = grid_result_dtc.cv_results_['mean_test_score']
stds = grid_result_dtc.cv_results_['std_test_score']
params = grid_result_dtc.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    

predicted_training_set_labels = grid_dtc.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = grid_dtc.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# Best: 0.607438 using {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'random'}
# 0.607438 (0.008094) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'random'}
# 0.574380 (0.005909) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 3, 'splitter': 'random'}
# 0.574380 (0.039231) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
# 0.570248 (0.045461) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
# 0.570248 (0.035441) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.566116 (0.027597) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3, 'splitter': 'random'}
# 0.561983 (0.015899) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.557851 (0.035481) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
# 0.553719 (0.013047) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.553719 (0.025440) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 3, 'splitter': 'random'}
# 0.545455 (0.022441) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
# 0.545455 (0.012065) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 4, 'splitter': 'best'}
# 0.545455 (0.027386) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 4, 'splitter': 'random'}
# 0.541322 (0.017545) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
# 0.537190 (0.005481) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.537190 (0.012877) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 4, 'splitter': 'random'}
# 0.537190 (0.012877) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'random'}
# 0.533058 (0.010166) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.533058 (0.020171) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
# 0.528926 (0.051591) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.528926 (0.034143) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.528926 (0.023473) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
# 0.528926 (0.007306) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
# 0.524793 (0.032967) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
# 0.524793 (0.023049) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.524793 (0.025903) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
# 0.524793 (0.014996) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.524793 (0.017873) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 3, 'splitter': 'best'}
# 0.524793 (0.021950) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
# 0.524793 (0.004837) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.524793 (0.035324) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.520661 (0.025877) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3, 'splitter': 'random'}
# 0.520661 (0.034348) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 4, 'splitter': 'best'}
# 0.520661 (0.010325) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'best'}
# 0.516529 (0.047001) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.516529 (0.047001) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.516529 (0.019100) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.516529 (0.010446) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
# 0.516529 (0.010446) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.516529 (0.010446) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3, 'splitter': 'best'}
# 0.512397 (0.027983) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
# 0.512397 (0.030751) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.512397 (0.013351) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.512397 (0.013351) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 3, 'splitter': 'best'}
# 0.512397 (0.013351) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
# 0.508264 (0.010608) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.508264 (0.028667) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.508264 (0.046000) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.504132 (0.037779) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.504132 (0.033599) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'best'}
# 0.504132 (0.054949) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.504132 (0.027856) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.500000 (0.028026) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.500000 (0.028164) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.500000 (0.028164) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3, 'splitter': 'best'}
# 0.500000 (0.013448) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.491736 (0.019124) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
# 0.491736 (0.025968) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.487603 (0.027937) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.487603 (0.026047) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
# 0.6983471074380165
# 0.5737704918032787

# %%
target_names=['class 0', 'class 1', 'class 2', 'class 3', 'class 4']
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.75      0.91      0.82        33
#     class 1       0.21      0.23      0.22        13
#     class 2       0.33      0.14      0.20         7
#     class 3       0.25      0.25      0.25         4
#     class 4       0.00      0.00      0.00         4
#
# avg / total       0.51      0.57      0.53        61
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# ax = plot.grid_search(grid_dtc.grid_scores_, change=('min_samples_leaf', 'min_samples_split'), 
#                       subset={'criterion': 'entropy', 'splitter': 'random'})
# fig = ax.get_figure()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('dataset2_dtc1.png')
# fig.clf()
# ax = plot.grid_search(grid_dtc.grid_scores_, change=('min_samples_leaf', 'min_samples_split'), 
#                       subset={'criterion': 'gini', 'splitter': 'random'})
# fig = ax.get_figure()
# fig.savefig('dataset2_dtc2.png')
# fig.clf()
# ax = plot.grid_search(grid_dtc.grid_scores_, change=('min_samples_leaf', 'min_samples_split'), 
#                       subset={'criterion': 'entropy', 'splitter': 'best'})
# fig = ax.get_figure()
# fig.savefig('dataset2_dtc3.png')
# fig.clf()
# ax = plot.grid_search(grid_dtc.grid_scores_, change=('min_samples_leaf', 'min_samples_split'), 
#                       subset={'criterion': 'gini', 'splitter': 'best'})
# fig = ax.get_figure()
# fig.savefig('dataset2_dtc4.png')
# fig.clf()

# %%
# dtc = tree.DecisionTreeClassifier(criterion= 'entropy', min_samples_leaf= 1, min_samples_split= 2, splitter= 'random')
# dtc.fit(training_set, training_set_labels)
# dot_data = tree.export_graphviz(dtc, out_file='dataset2_tree.dot', feature_names=training_set.columns, 
#                                 filled=True, rounded=True)  
# graph = graphviz.Source(dot_data)
# from subprocess import check_call
# #check_call(['dot','-Tpng','dataset2_tree.dot','-o','dataset2_tree.png'])

# %%
# neural networks
nn = MLPClassifier()
nn.fit(training_set, training_set_labels)

predicted_training_set_labels = nn.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = nn.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# 0.5578512396694215
# 0.5081967213114754

# %%
alphas = [0.0001, 0.0002, 0.0005, 0.0007, 0.001, 0.002, 0.005, 0.01]
learning_rates = [0.001, 0.002, 0.005, 0.007, 0.01]
momentums = [0.9, 0.85, 0.8, 0.75, 0.7]
param_grid = dict(alpha=alphas, learning_rate_init = learning_rates, momentum = momentums)
grid_nn = GridSearchCV(estimator=nn, param_grid=param_grid)
grid_result_nn = grid_nn.fit(training_set, training_set_labels)


print("Best: %f using %s" % (grid_result_nn.best_score_, grid_result_nn.best_params_))
means = grid_result_nn.cv_results_['mean_test_score']
stds = grid_result_nn.cv_results_['std_test_score']
params = grid_result_nn.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    

predicted_training_set_labels = grid_nn.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc_nn=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = grid_nn.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc_nn=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc_nn)
print(testing_set_acc_nn)
# Out:
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...
# 0.553719 (0.020067) with: {'alpha': 0.0002, 'learning_rate_init': 0.002, 'momentum': 0.9}
# 0.553719 (0.017506) with: {'alpha': 0.0002, 'learning_rate_init': 0.007, 'momentum': 0.75}
# 0.553719 (0.020067) with: {'alpha': 0.0002, 'learning_rate_init': 0.01, 'momentum': 0.7}
# 0.553719 (0.020067) with: {'alpha': 0.0007, 'learning_rate_init': 0.002, 'momentum': 0.9}
# 0.553719 (0.026436) with: {'alpha': 0.0007, 'learning_rate_init': 0.005, 'momentum': 0.8}
# 0.553719 (0.025010) with: {'alpha': 0.0007, 'learning_rate_init': 0.007, 'momentum': 0.75}
# 0.553719 (0.020067) with: {'alpha': 0.001, 'learning_rate_init': 0.01, 'momentum': 0.7}
# 0.553719 (0.013932) with: {'alpha': 0.002, 'learning_rate_init': 0.007, 'momentum': 0.75}
# 0.553719 (0.020067) with: {'alpha': 0.005, 'learning_rate_init': 0.007, 'momentum': 0.9}
# 0.553719 (0.007632) with: {'alpha': 0.01, 'learning_rate_init': 0.007, 'momentum': 0.85}
# 0.549587 (0.013366) with: {'alpha': 0.0001, 'learning_rate_init': 0.002, 'momentum': 0.8}
# 0.549587 (0.022880) with: {'alpha': 0.0001, 'learning_rate_init': 0.005, 'momentum': 0.85}
# 0.549587 (0.004610) with: {'alpha': 0.0001, 'learning_rate_init': 0.005, 'momentum': 0.8}
# 0.549587 (0.008165) with: {'alpha': 0.0001, 'learning_rate_init': 0.007, 'momentum': 0.85}
# 0.549587 (0.027676) with: {'alpha': 0.0002, 'learning_rate_init': 0.007, 'momentum': 0.9}
# 0.549587 (0.008165) with: {'alpha': 0.0005, 'learning_rate_init': 0.002, 'momentum': 0.9}
# 0.549587 (0.014209) with: {'alpha': 0.0005, 'learning_rate_init': 0.002, 'momentum': 0.85}
# 0.549587 (0.008165) with: {'alpha': 0.0005, 'learning_rate_init': 0.01, 'momentum': 0.85}
# 0.549587 (0.008165) with: {'alpha': 0.0007, 'learning_rate_init': 0.002, 'momentum': 0.7}
# 0.549587 (0.008165) with: {'alpha': 0.0007, 'learning_rate_init': 0.005, 'momentum': 0.9}
# 0.549587 (0.017746) with: {'alpha': 0.0007, 'learning_rate_init': 0.005, 'momentum': 0.75}
# 0.549587 (0.008165) with: {'alpha': 0.0007, 'learning_rate_init': 0.007, 'momentum': 0.85}
# 0.549587 (0.008165) with: {'alpha': 0.0007, 'learning_rate_init': 0.007, 'momentum': 0.8}
# 0.549587 (0.008165) with: {'alpha': 0.0007, 'learning_rate_init': 0.01, 'momentum': 0.8}
# 0.549587 (0.004610) with: {'alpha': 0.001, 'learning_rate_init': 0.002, 'momentum': 0.85}
# 0.549587 (0.013366) with: {'alpha': 0.001, 'learning_rate_init': 0.005, 'momentum': 0.9}
# 0.549587 (0.008165) with: {'alpha': 0.001, 'learning_rate_init': 0.007, 'momentum': 0.85}
# 0.549587 (0.009325) with: {'alpha': 0.001, 'learning_rate_init': 0.01, 'momentum': 0.8}
# 0.549587 (0.023006) with: {'alpha': 0.002, 'learning_rate_init': 0.005, 'momentum': 0.8}
# 0.549587 (0.014209) with: {'alpha': 0.002, 'learning_rate_init': 0.01, 'momentum': 0.75}
# 0.549587 (0.008165) with: {'alpha': 0.005, 'learning_rate_init': 0.007, 'momentum': 0.85}
# 0.549587 (0.005620) with: {'alpha': 0.005, 'learning_rate_init': 0.01, 'momentum': 0.9}
# 0.549587 (0.014209) with: {'alpha': 0.01, 'learning_rate_init': 0.002, 'momentum': 0.9}
# 0.549587 (0.025927) with: {'alpha': 0.01, 'learning_rate_init': 0.005, 'momentum': 0.75}
# 0.549587 (0.015766) with: {'alpha': 0.01, 'learning_rate_init': 0.005, 'momentum': 0.7}
# 0.545455 (0.007825) with: {'alpha': 0.0001, 'learning_rate_init': 0.002, 'momentum': 0.7}
# 0.545455 (0.016987) with: {'alpha': 0.0001, 'learning_rate_init': 0.005, 'momentum': 0.9}
# 0.545455 (0.008460) with: {'alpha': 0.0001, 'learning_rate_init': 0.007, 'momentum': 0.8}
# 0.545455 (0.008460) with: {'alpha': 0.0001, 'learning_rate_init': 0.01, 'momentum': 0.8}
# 0.545455 (0.007825) with: {'alpha': 0.0002, 'learning_rate_init': 0.001, 'momentum': 0.9}
# 0.545455 (0.007825) with: {'alpha': 0.0002, 'learning_rate_init': 0.007, 'momentum': 0.85}
# 0.545455 (0.008460) with: {'alpha': 0.0002, 'learning_rate_init': 0.007, 'momentum': 0.8}
# 0.545455 (0.002422) with: {'alpha': 0.0005, 'learning_rate_init': 0.007, 'momentum': 0.8}
# 0.545455 (0.002422) with: {'alpha': 0.0005, 'learning_rate_init': 0.01, 'momentum': 0.8}
# 0.545455 (0.008460) with: {'alpha': 0.0005, 'learning_rate_init': 0.01, 'momentum': 0.75}
# 0.545455 (0.007825) with: {'alpha': 0.0007, 'learning_rate_init': 0.002, 'momentum': 0.75}
# 0.545455 (0.026686) with: {'alpha': 0.0007, 'learning_rate_init': 0.005, 'momentum': 0.85}
# 0.545455 (0.008460) with: {'alpha': 0.0007, 'learning_rate_init': 0.01, 'momentum': 0.75}
# 0.545455 (0.008460) with: {'alpha': 0.001, 'learning_rate_init': 0.002, 'momentum': 0.75}
# 0.545455 (0.008460) with: {'alpha': 0.001, 'learning_rate_init': 0.007, 'momentum': 0.9}
# 0.545455 (0.007825) with: {'alpha': 0.002, 'learning_rate_init': 0.002, 'momentum': 0.9}
# 0.545455 (0.002422) with: {'alpha': 0.002, 'learning_rate_init': 0.005, 'momentum': 0.85}
# 0.545455 (0.028085) with: {'alpha': 0.002, 'learning_rate_init': 0.005, 'momentum': 0.75}
# 0.545455 (0.008460) with: {'alpha': 0.002, 'learning_rate_init': 0.007, 'momentum': 0.8}
# 0.545455 (0.007825) with: {'alpha': 0.002, 'learning_rate_init': 0.01, 'momentum': 0.9}
# 0.545455 (0.008460) with: {'alpha': 0.002, 'learning_rate_init': 0.01, 'momentum': 0.85}
# 0.545455 (0.008460) with: {'alpha': 0.005, 'learning_rate_init': 0.005, 'momentum': 0.9}
# 0.545455 (0.026686) with: {'alpha': 0.005, 'learning_rate_init': 0.005, 'momentum': 0.75}
# 0.545455 (0.008460) with: {'alpha': 0.005, 'learning_rate_init': 0.007, 'momentum': 0.75}
# 0.545455 (0.008460) with: {'alpha': 0.005, 'learning_rate_init': 0.007, 'momentum': 0.7}
# 0.545455 (0.002422) with: {'alpha': 0.01, 'learning_rate_init': 0.005, 'momentum': 0.85}
# 0.545455 (0.007825) with: {'alpha': 0.01, 'learning_rate_init': 0.007, 'momentum': 0.75}
# 0.545455 (0.012382) with: {'alpha': 0.01, 'learning_rate_init': 0.01, 'momentum': 0.85}
# 0.545455 (0.008460) with: {'alpha': 0.01, 'learning_rate_init': 0.01, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.001, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.001, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.001, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.001, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.001, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.002, 'momentum': 0.75}
# 0.541322 (0.017545) with: {'alpha': 0.0001, 'learning_rate_init': 0.005, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.005, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.01, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.01, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.01, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0001, 'learning_rate_init': 0.01, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.001, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.001, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.001, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.001, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.002, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.002, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.002, 'momentum': 0.7}
# 0.541322 (0.021049) with: {'alpha': 0.0002, 'learning_rate_init': 0.005, 'momentum': 0.9}
# 0.541322 (0.016515) with: {'alpha': 0.0002, 'learning_rate_init': 0.005, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.01, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.01, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.01, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.0002, 'learning_rate_init': 0.01, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.001, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.001, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.001, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.001, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.001, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.002, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.002, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.002, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.005, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.007, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.0005, 'learning_rate_init': 0.007, 'momentum': 0.75}
# 0.541322 (0.007639) with: {'alpha': 0.0005, 'learning_rate_init': 0.01, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.001, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.001, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.001, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.001, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.002, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.002, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.007, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.01, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.0007, 'learning_rate_init': 0.01, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.001, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.001, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.001, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.001, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.001, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.002, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.002, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.002, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.005, 'momentum': 0.85}
# 0.541322 (0.021049) with: {'alpha': 0.001, 'learning_rate_init': 0.007, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.01, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.01, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.001, 'learning_rate_init': 0.01, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.001, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.001, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.001, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.001, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.001, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.002, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.002, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.002, 'momentum': 0.7}
# 0.541322 (0.007114) with: {'alpha': 0.002, 'learning_rate_init': 0.005, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.005, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.007, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.01, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.002, 'learning_rate_init': 0.01, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.001, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.001, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.001, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.001, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.001, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.002, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.002, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.002, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.002, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.002, 'momentum': 0.7}
# 0.541322 (0.017545) with: {'alpha': 0.005, 'learning_rate_init': 0.005, 'momentum': 0.85}
# 0.541322 (0.021049) with: {'alpha': 0.005, 'learning_rate_init': 0.01, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.01, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.005, 'learning_rate_init': 0.01, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.001, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.001, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.001, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.001, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.001, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.002, 'momentum': 0.85}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.002, 'momentum': 0.75}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.002, 'momentum': 0.7}
# 0.541322 (0.019879) with: {'alpha': 0.01, 'learning_rate_init': 0.005, 'momentum': 0.9}
# 0.541322 (0.014073) with: {'alpha': 0.01, 'learning_rate_init': 0.005, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.007, 'momentum': 0.7}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.01, 'momentum': 0.9}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.01, 'momentum': 0.8}
# 0.541322 (0.003420) with: {'alpha': 0.01, 'learning_rate_init': 0.01, 'momentum': 0.75}
# 0.537190 (0.008304) with: {'alpha': 0.0005, 'learning_rate_init': 0.005, 'momentum': 0.85}
# 0.537190 (0.005481) with: {'alpha': 0.0007, 'learning_rate_init': 0.001, 'momentum': 0.9}
# 0.537190 (0.005481) with: {'alpha': 0.0007, 'learning_rate_init': 0.007, 'momentum': 0.9}
# 0.537190 (0.013369) with: {'alpha': 0.001, 'learning_rate_init': 0.007, 'momentum': 0.8}
# 0.537190 (0.018469) with: {'alpha': 0.002, 'learning_rate_init': 0.007, 'momentum': 0.9}
# 0.537190 (0.009174) with: {'alpha': 0.005, 'learning_rate_init': 0.007, 'momentum': 0.8}
# 0.537190 (0.005481) with: {'alpha': 0.01, 'learning_rate_init': 0.002, 'momentum': 0.8}
# 0.537190 (0.005481) with: {'alpha': 0.01, 'learning_rate_init': 0.007, 'momentum': 0.9}
# 0.537190 (0.013369) with: {'alpha': 0.01, 'learning_rate_init': 0.007, 'momentum': 0.8}
# 0.533058 (0.010782) with: {'alpha': 0.0001, 'learning_rate_init': 0.007, 'momentum': 0.9}
# 0.533058 (0.014942) with: {'alpha': 0.0005, 'learning_rate_init': 0.007, 'momentum': 0.85}
# 0.533058 (0.010782) with: {'alpha': 0.0007, 'learning_rate_init': 0.01, 'momentum': 0.9}
# 0.533058 (0.010782) with: {'alpha': 0.001, 'learning_rate_init': 0.007, 'momentum': 0.75}
# 0.528926 (0.019690) with: {'alpha': 0.0005, 'learning_rate_init': 0.005, 'momentum': 0.9}
# 0.5413223140495868
# 0.5409836065573771

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.54      1.00      0.70        33
#     class 1       0.00      0.00      0.00        13
#     class 2       0.00      0.00      0.00         7
#     class 3       0.00      0.00      0.00         4
#     class 4       0.00      0.00      0.00         4
#
# avg / total       0.29      0.54      0.38        61
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# ax = plot.grid_search(grid_nn.grid_scores_, change=('alpha', 'learning_rate_init'),
#               subset={'momentum': 0.85})
# fig = ax.get_figure()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('dataset2_NN1.png')
# fig.clf()
# ax = plot.grid_search(grid_nn.grid_scores_, change=('alpha', 'momentum'),
#               subset={'learning_rate_init': 0.005})
# fig = ax.get_figure()
# fig.savefig('dataset2_NN2.png')
# fig.clf()

# %%
# boosting
gbc = GradientBoostingClassifier()
gbc.fit(training_set, training_set_labels)

predicted_training_set_labels = gbc.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = gbc.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# 1.0
# 0.5245901639344263

# %%
nEstimators = [100, 300, 500, 700, 900]
learning_rates = [0.1, 0.3, 0.5, 0.7, 1.0]
param_grid = dict(learning_rate = learning_rates, n_estimators = nEstimators)
grid_b = GridSearchCV(estimator=gbc, param_grid=param_grid)
grid_result_b = grid_b.fit(training_set, training_set_labels)


print("Best: %f using %s" % (grid_result_b.best_score_, grid_result_b.best_params_))
means = grid_result_b.cv_results_['mean_test_score']
stds = grid_result_b.cv_results_['std_test_score']
params = grid_result_b.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    
predicted_training_set_labels = grid_b.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = grid_b.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# Best: 0.586777 using {'learning_rate': 0.3, 'n_estimators': 300}
# 0.586777 (0.036480) with: {'learning_rate': 0.3, 'n_estimators': 300}
# 0.586777 (0.026321) with: {'learning_rate': 0.5, 'n_estimators': 500}
# 0.586777 (0.032921) with: {'learning_rate': 0.5, 'n_estimators': 900}
# 0.586777 (0.014781) with: {'learning_rate': 0.7, 'n_estimators': 500}
# 0.582645 (0.017504) with: {'learning_rate': 0.1, 'n_estimators': 100}
# 0.582645 (0.037091) with: {'learning_rate': 0.3, 'n_estimators': 100}
# 0.582645 (0.037091) with: {'learning_rate': 0.3, 'n_estimators': 500}
# 0.582645 (0.009037) with: {'learning_rate': 0.7, 'n_estimators': 100}
# 0.578512 (0.038567) with: {'learning_rate': 0.3, 'n_estimators': 700}
# 0.578512 (0.036669) with: {'learning_rate': 0.5, 'n_estimators': 300}
# 0.578512 (0.013902) with: {'learning_rate': 0.7, 'n_estimators': 300}
# 0.578512 (0.021498) with: {'learning_rate': 0.7, 'n_estimators': 900}
# 0.574380 (0.042580) with: {'learning_rate': 0.3, 'n_estimators': 900}
# 0.574380 (0.032757) with: {'learning_rate': 0.5, 'n_estimators': 100}
# 0.574380 (0.042580) with: {'learning_rate': 0.5, 'n_estimators': 700}
# 0.570248 (0.017331) with: {'learning_rate': 0.7, 'n_estimators': 700}
# 0.561983 (0.013395) with: {'learning_rate': 1.0, 'n_estimators': 100}
# 0.561983 (0.017648) with: {'learning_rate': 1.0, 'n_estimators': 300}
# 0.557851 (0.051444) with: {'learning_rate': 0.1, 'n_estimators': 700}
# 0.557851 (0.046829) with: {'learning_rate': 0.1, 'n_estimators': 900}
# 0.557851 (0.019702) with: {'learning_rate': 1.0, 'n_estimators': 700}
# 0.553719 (0.051517) with: {'learning_rate': 0.1, 'n_estimators': 300}
# 0.553719 (0.051517) with: {'learning_rate': 0.1, 'n_estimators': 500}
# 0.553719 (0.013932) with: {'learning_rate': 1.0, 'n_estimators': 900}
# 0.549587 (0.008165) with: {'learning_rate': 1.0, 'n_estimators': 500}
# 1.0
# 0.5081967213114754

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.73      0.82      0.77        33
#     class 1       0.23      0.23      0.23        13
#     class 2       0.00      0.00      0.00         7
#     class 3       0.14      0.25      0.18         4
#     class 4       0.00      0.00      0.00         4
#
# avg / total       0.45      0.51      0.48        61
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# ax = plot.grid_search(grid_b.grid_scores_, change=('learning_rate', 'n_estimators'))
# fig = ax.get_figure()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('dataset2_boosting1.png')
# fig.clf()

# %%
# KNN
knn = KNeighborsClassifier()
knn.fit(training_set, training_set_labels)

predicted_training_set_labels = knn.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = knn.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# 0.6115702479338843
# 0.45901639344262296

# %%
n_neighbors = [5, 6, 7, 8, 9, 10]
weights = ["uniform", "distance"]
p = [1, 2, 3, 4]
param_grid = dict(n_neighbors = n_neighbors, weights = weights, p = p)
grid_knn = GridSearchCV(estimator=knn, param_grid=param_grid)
grid_result_knn = grid_knn.fit(training_set, training_set_labels)


print("Best: %f using %s" % (grid_result_knn.best_score_, grid_result_knn.best_params_))
means = grid_result_knn.cv_results_['mean_test_score']
stds = grid_result_knn.cv_results_['std_test_score']
params = grid_result_knn.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    

predicted_training_set_labels = grid_knn.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = grid_knn.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# Best: 0.578512 using {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.578512 (0.016744) with: {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.566116 (0.028967) with: {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.561983 (0.026925) with: {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.557851 (0.002309) with: {'n_neighbors': 8, 'p': 1, 'weights': 'uniform'}
# 0.553719 (0.023031) with: {'n_neighbors': 6, 'p': 1, 'weights': 'uniform'}
# 0.553719 (0.010224) with: {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.553719 (0.033763) with: {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.553719 (0.049597) with: {'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.549587 (0.005620) with: {'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.545455 (0.019844) with: {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.545455 (0.008460) with: {'n_neighbors': 10, 'p': 4, 'weights': 'uniform'}
# 0.537190 (0.028300) with: {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.537190 (0.031416) with: {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.537190 (0.043172) with: {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.537190 (0.035814) with: {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.537190 (0.008304) with: {'n_neighbors': 9, 'p': 3, 'weights': 'uniform'}
# 0.537190 (0.013369) with: {'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.528926 (0.029791) with: {'n_neighbors': 6, 'p': 1, 'weights': 'distance'}
# 0.528926 (0.039355) with: {'n_neighbors': 7, 'p': 4, 'weights': 'uniform'}
# 0.528926 (0.029791) with: {'n_neighbors': 8, 'p': 1, 'weights': 'distance'}
# 0.528926 (0.007306) with: {'n_neighbors': 9, 'p': 4, 'weights': 'uniform'}
# 0.524793 (0.030685) with: {'n_neighbors': 5, 'p': 4, 'weights': 'uniform'}
# 0.524793 (0.022880) with: {'n_neighbors': 8, 'p': 2, 'weights': 'uniform'}
# 0.524793 (0.015504) with: {'n_neighbors': 8, 'p': 3, 'weights': 'uniform'}
# 0.524793 (0.018571) with: {'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.520661 (0.018129) with: {'n_neighbors': 8, 'p': 4, 'weights': 'uniform'}
# 0.516529 (0.037252) with: {'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.516529 (0.012981) with: {'n_neighbors': 6, 'p': 2, 'weights': 'uniform'}
# 0.516529 (0.029669) with: {'n_neighbors': 7, 'p': 3, 'weights': 'uniform'}
# 0.516529 (0.029799) with: {'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.516529 (0.023081) with: {'n_neighbors': 10, 'p': 4, 'weights': 'distance'}
# 0.512397 (0.022008) with: {'n_neighbors': 6, 'p': 3, 'weights': 'uniform'}
# 0.512397 (0.035489) with: {'n_neighbors': 9, 'p': 4, 'weights': 'distance'}
# 0.508264 (0.016236) with: {'n_neighbors': 6, 'p': 4, 'weights': 'uniform'}
# 0.508264 (0.032109) with: {'n_neighbors': 9, 'p': 3, 'weights': 'distance'}
# 0.504132 (0.033015) with: {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.504132 (0.022725) with: {'n_neighbors': 7, 'p': 4, 'weights': 'distance'}
# 0.500000 (0.026192) with: {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.500000 (0.033272) with: {'n_neighbors': 8, 'p': 3, 'weights': 'distance'}
# 0.500000 (0.044893) with: {'n_neighbors': 8, 'p': 4, 'weights': 'distance'}
# 0.495868 (0.033483) with: {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.483471 (0.031819) with: {'n_neighbors': 6, 'p': 2, 'weights': 'distance'}
# 0.483471 (0.027669) with: {'n_neighbors': 7, 'p': 3, 'weights': 'distance'}
# 0.483471 (0.017629) with: {'n_neighbors': 8, 'p': 2, 'weights': 'distance'}
# 0.479339 (0.038925) with: {'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.479339 (0.048727) with: {'n_neighbors': 5, 'p': 4, 'weights': 'distance'}
# 0.475207 (0.025903) with: {'n_neighbors': 6, 'p': 3, 'weights': 'distance'}
# 0.475207 (0.032967) with: {'n_neighbors': 6, 'p': 4, 'weights': 'distance'}
# 0.6033057851239669
# 0.5081967213114754

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.64      0.91      0.75        33
#     class 1       0.14      0.08      0.10        13
#     class 2       0.00      0.00      0.00         7
#     class 3       0.00      0.00      0.00         4
#     class 4       0.00      0.00      0.00         4
#
# avg / total       0.38      0.51      0.43        61
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# ax = plot.grid_search(grid_knn.grid_scores_, change=('n_neighbors', 'p'), subset={'weights': 'uniform'})
# fig = ax.get_figure()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('dataset2_knn1.png')
# fig.clf()
# ax = plot.grid_search(grid_knn.grid_scores_, change=('n_neighbors', 'p'), subset={'weights': 'distance'})
# fig = ax.get_figure()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('dataset2_knn2.png')
# fig.clf()

# %%
# SVM
svm_c = svm.SVC()
svm_c.fit(training_set, training_set_labels)

predicted_training_set_labels = svm_c.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = svm_c.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# 1.0
# 0.5409836065573771

# %%
C_range = 10. ** np.arange(-3, 8)
gamma_range = 10. ** np.arange(-5, 4)
param_grid = dict(C = C_range, gamma = gamma_range)
grid_svc = GridSearchCV(estimator=svm_c, param_grid=param_grid)
grid_result_svc = grid_svc.fit(training_set, training_set_labels)


print("Best: %f using %s" % (grid_result_svc.best_score_, grid_result_svc.best_params_))
means = grid_result_svc.cv_results_['mean_test_score']
stds = grid_result_svc.cv_results_['std_test_score']
params = grid_result_svc.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    

predicted_training_set_labels = grid_svc.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = grid_svc.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# Best: 0.570248 using {'C': 1000.0, 'gamma': 1e-05}
# 0.570248 (0.029002) with: {'C': 1000.0, 'gamma': 1e-05}
# 0.570248 (0.018183) with: {'C': 100000.0, 'gamma': 1e-05}
# 0.566116 (0.019074) with: {'C': 100.0, 'gamma': 1e-05}
# 0.566116 (0.021157) with: {'C': 100.0, 'gamma': 0.0001}
# 0.566116 (0.035304) with: {'C': 10000.0, 'gamma': 1e-05}
# 0.557851 (0.041844) with: {'C': 10000000.0, 'gamma': 1e-05}
# 0.549587 (0.034040) with: {'C': 1000000.0, 'gamma': 1e-05}
# 0.545455 (0.002422) with: {'C': 1.0, 'gamma': 0.0001}
# 0.545455 (0.015091) with: {'C': 1.0, 'gamma': 0.001}
# 0.545455 (0.008460) with: {'C': 1.0, 'gamma': 0.01}
# 0.545455 (0.002422) with: {'C': 10.0, 'gamma': 1e-05}
# 0.545455 (0.010873) with: {'C': 10.0, 'gamma': 0.0001}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 1e-05}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 0.0001}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 0.001}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 0.01}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 0.001, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 1e-05}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 0.0001}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 0.001}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 0.01}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 0.01, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 1e-05}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 0.0001}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 0.001}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 0.01}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 0.1, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 1.0, 'gamma': 1e-05}
# 0.541322 (0.003420) with: {'C': 1.0, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 1.0, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 1.0, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 1.0, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 1.0, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 10.0, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 10.0, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 10.0, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 10.0, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 10.0, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 100.0, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 100.0, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 100.0, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 100.0, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 100.0, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 1000.0, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 1000.0, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 1000.0, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 1000.0, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 1000.0, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 10000.0, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 10000.0, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 10000.0, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 10000.0, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 10000.0, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 100000.0, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 100000.0, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 100000.0, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 100000.0, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 100000.0, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 1000000.0, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 1000000.0, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 1000000.0, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 1000000.0, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 1000000.0, 'gamma': 1000.0}
# 0.541322 (0.003420) with: {'C': 10000000.0, 'gamma': 0.1}
# 0.541322 (0.003420) with: {'C': 10000000.0, 'gamma': 1.0}
# 0.541322 (0.003420) with: {'C': 10000000.0, 'gamma': 10.0}
# 0.541322 (0.003420) with: {'C': 10000000.0, 'gamma': 100.0}
# 0.541322 (0.003420) with: {'C': 10000000.0, 'gamma': 1000.0}
# 0.537190 (0.009174) with: {'C': 10.0, 'gamma': 0.01}
# 0.537190 (0.009174) with: {'C': 100.0, 'gamma': 0.01}
# 0.537190 (0.009174) with: {'C': 1000.0, 'gamma': 0.01}
# 0.537190 (0.009174) with: {'C': 10000.0, 'gamma': 0.01}
# 0.537190 (0.009174) with: {'C': 100000.0, 'gamma': 0.01}
# 0.537190 (0.009174) with: {'C': 1000000.0, 'gamma': 0.01}
# 0.537190 (0.009174) with: {'C': 10000000.0, 'gamma': 0.01}
# 0.533058 (0.037946) with: {'C': 1000.0, 'gamma': 0.0001}
# 0.520661 (0.042967) with: {'C': 10000.0, 'gamma': 0.0001}
# 0.516529 (0.036517) with: {'C': 100000.0, 'gamma': 0.0001}
# 0.516529 (0.036517) with: {'C': 1000000.0, 'gamma': 0.0001}
# 0.516529 (0.036517) with: {'C': 10000000.0, 'gamma': 0.0001}
# 0.462810 (0.015634) with: {'C': 10.0, 'gamma': 0.001}
# 0.454545 (0.019176) with: {'C': 100.0, 'gamma': 0.001}
# 0.446281 (0.017506) with: {'C': 1000.0, 'gamma': 0.001}
# 0.446281 (0.017506) with: {'C': 10000.0, 'gamma': 0.001}
# 0.446281 (0.017506) with: {'C': 100000.0, 'gamma': 0.001}
# 0.446281 (0.017506) with: {'C': 1000000.0, 'gamma': 0.001}
# 0.446281 (0.017506) with: {'C': 10000000.0, 'gamma': 0.001}
# 0.7066115702479339
# 0.5409836065573771

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.69      0.88      0.77        33
#     class 1       0.22      0.15      0.18        13
#     class 2       0.50      0.29      0.36         7
#     class 3       0.00      0.00      0.00         4
#     class 4       0.00      0.00      0.00         4
#
# avg / total       0.48      0.54      0.50        61

# %%
# ax = plot.grid_search(grid_svc.grid_scores_, change=('C', 'gamma'))
# fig = ax.get_figure()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('dataset2_svm.png')
# fig.clf()

# %%
linear_svc=svm.LinearSVC()
C_range = 10. ** np.arange(-3, 8)

param_grid = dict(C = C_range)
grid_linear_svc = GridSearchCV(estimator=linear_svc, param_grid=param_grid)
grid_result_linear_svc = grid_linear_svc.fit(training_set, training_set_labels)


print("Best: %f using %s" % (grid_result_linear_svc.best_score_, grid_result_linear_svc.best_params_))
means = grid_result_linear_svc.cv_results_['mean_test_score']
stds = grid_result_linear_svc.cv_results_['std_test_score']
params = grid_result_linear_svc.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    

predicted_training_set_labels = grid_result_linear_svc.predict(training_set)
predicted_training_set_labels = pd.DataFrame(predicted_training_set_labels) 
training_set_acc=accuracy_score(training_set_labels, predicted_training_set_labels)

predicted_testing_set_labels = grid_result_linear_svc.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)

print(training_set_acc)
print(testing_set_acc)
# Out:
# Best: 0.628099 using {'C': 100000.0}
# 0.628099 (0.030799) with: {'C': 100000.0}
# 0.599174 (0.022591) with: {'C': 0.001}
# 0.595041 (0.019460) with: {'C': 0.01}
# 0.586777 (0.029635) with: {'C': 0.1}
# 0.586777 (0.058596) with: {'C': 1.0}
# 0.561983 (0.013395) with: {'C': 10000.0}
# 0.537190 (0.092253) with: {'C': 1000000.0}
# 0.508264 (0.135528) with: {'C': 10.0}
# 0.466942 (0.217569) with: {'C': 100.0}
# 0.462810 (0.071300) with: {'C': 10000000.0}
# 0.446281 (0.196292) with: {'C': 1000.0}
# 0.6198347107438017
# 0.5409836065573771

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.59      0.97      0.74        33
#     class 1       0.00      0.00      0.00        13
#     class 2       0.00      0.00      0.00         7
#     class 3       0.17      0.25      0.20         4
#     class 4       0.00      0.00      0.00         4
#
# avg / total       0.33      0.54      0.41        61
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# upsampling data
training_set2, testing_set2 = loadData.loadDataWithoutTestSet('processed.cleveland.data', split_to_test=True)
class_0 = training_set2[training_set2['cancerPresence']==0]
num=len(class_0)
class_1 = training_set2[training_set2['cancerPresence']==1]
class_2 = training_set2[training_set2['cancerPresence']==2]
class_3 = training_set2[training_set2['cancerPresence']==3]
class_4 = training_set2[training_set2['cancerPresence']==4]
class_1_upsampled = resample(class_1, 
                                 replace=True,   
                                 n_samples=num,   
                                 random_state=123)
class_2_upsampled = resample(class_2, 
                                 replace=True,   
                                 n_samples=num,   
                                 random_state=123)
class_3_upsampled = resample(class_3, 
                                 replace=True,   
                                 n_samples=num,   
                                 random_state=123)
class_4_upsampled = resample(class_4, 
                                 replace=True,   
                                 n_samples=num,   
                                 random_state=123)
training_set_upsampled=pd.concat([class_0, class_1_upsampled, class_2_upsampled, class_3_upsampled, class_4_upsampled])
training_set_upsampled_labels = training_set_upsampled.iloc[:,-1]
training_set_upsampled = training_set_upsampled.iloc[:,0:-1]

training_set_upsampled_labels.reset_index(drop=True, inplace=True)
training_set_upsampled.reset_index(drop=True, inplace=True)
training_set_upsampled.replace('?',0, inplace=True)

training_set_upsampled[['ca','thal']] = training_set_upsampled[['ca','thal']].apply(pd.to_numeric)


plt.bar(['0','1', '2', '3', '4'],[len(training_set_upsampled_labels[training_set_upsampled_labels==0]), 
         len(training_set_upsampled_labels[training_set_upsampled_labels==1]), 
             len(training_set_upsampled_labels[training_set_upsampled_labels==2]),
                len(training_set_upsampled_labels[training_set_upsampled_labels==3]),
                   len(training_set_upsampled_labels[training_set_upsampled_labels==4])])
plt.title('Upsampled Training Set Label Distribution')
plt.show()

# %%
criterion = ['gini', 'entropy']
splitter  = ['best','random']
min_samples_split = [2, 3, 4]
min_samples_leaf = [1, 2, 3, 4, 5]
param_grid = dict(criterion = criterion, splitter = splitter, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
grid_dtc = GridSearchCV(estimator=dtc, param_grid=param_grid)
grid_result_dtc = grid_dtc.fit(training_set_upsampled, training_set_upsampled_labels)


print("Best: %f using %s" % (grid_result_dtc.best_score_, grid_result_dtc.best_params_))
means = grid_result_dtc.cv_results_['mean_test_score']
stds = grid_result_dtc.cv_results_['std_test_score']
params = grid_result_dtc.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))

predicted_testing_set_labels = grid_dtc.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)
# Out:
# Best: 0.912593 using {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.912593 (0.027237) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.909630 (0.009132) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.903704 (0.015108) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.899259 (0.012744) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
# 0.897778 (0.013084) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.897778 (0.018856) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.896296 (0.019986) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.896296 (0.014666) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
# 0.891852 (0.027237) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.887407 (0.019986) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.882963 (0.010476) with: {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
# 0.881481 (0.019986) with: {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
# 0.865185 (0.022173) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.862222 (0.032254) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
# 0.860741 (0.024162) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.859259 (0.026252) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
# 0.856296 (0.021263) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.848889 (0.026168) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
# 0.847407 (0.020635) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
# 0.845926 (0.018265) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.842963 (0.029332) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.842963 (0.023046) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.842963 (0.034299) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 4, 'splitter': 'best'}
# 0.841481 (0.036349) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.838519 (0.022173) with: {'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.837037 (0.018622) with: {'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.832593 (0.026749) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.825185 (0.005543) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.825185 (0.030863) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 4, 'splitter': 'best'}
# 0.819259 (0.030863) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.819259 (0.032727) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.819259 (0.024162) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 4, 'splitter': 'random'}
# 0.817778 (0.032254) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.805926 (0.010476) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 3, 'splitter': 'best'}
# 0.801481 (0.017901) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.798519 (0.020951) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
# 0.797037 (0.019986) with: {'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.792593 (0.030863) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
# 0.792593 (0.018265) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
# 0.791111 (0.022662) with: {'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 4, 'splitter': 'random'}
# 0.786667 (0.033259) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 3, 'splitter': 'best'}
# 0.783704 (0.035246) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
# 0.773333 (0.016630) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.773333 (0.016630) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3, 'splitter': 'best'}
# 0.767407 (0.019986) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
# 0.764444 (0.016630) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 3, 'splitter': 'random'}
# 0.760000 (0.026168) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'best'}
# 0.757037 (0.049001) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
# 0.757037 (0.027477) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.755556 (0.031636) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'best'}
# 0.755556 (0.012571) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 3, 'splitter': 'random'}
# 0.754074 (0.030216) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3, 'splitter': 'best'}
# 0.745185 (0.019986) with: {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
# 0.740741 (0.047361) with: {'criterion': 'entropy', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
# 0.727407 (0.030863) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.715556 (0.042784) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.696296 (0.030863) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'random'}
# 0.693333 (0.009601) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 4, 'splitter': 'random'}
# 0.682963 (0.036349) with: {'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3, 'splitter': 'random'}
# 0.675556 (0.013084) with: {'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3, 'splitter': 'random'}

# %%
ax = plot.grid_search(grid_dtc.grid_scores_, change=('min_samples_leaf', 'min_samples_split'), 
                      subset={'criterion': 'entropy', 'splitter': 'random'})
fig = ax.get_figure()
fig.set_size_inches(18.5, 10.5)
fig.savefig('dataset2_dtc1.png')
fig.clf()
ax = plot.grid_search(grid_dtc.grid_scores_, change=('min_samples_leaf', 'min_samples_split'), 
                      subset={'criterion': 'gini', 'splitter': 'random'})
fig = ax.get_figure()
fig.savefig('dataset2_dtc2.png')
fig.clf()
ax = plot.grid_search(grid_dtc.grid_scores_, change=('min_samples_leaf', 'min_samples_split'), 
                      subset={'criterion': 'entropy', 'splitter': 'best'})
fig = ax.get_figure()
fig.savefig('dataset2_dtc3.png')
fig.clf()
ax = plot.grid_search(grid_dtc.grid_scores_, change=('min_samples_leaf', 'min_samples_split'), 
                      subset={'criterion': 'gini', 'splitter': 'best'})
fig = ax.get_figure()
fig.savefig('dataset2_dtc4.png')
fig.clf()
# Out:
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.91      0.94      0.93        33
#     class 1       0.82      0.69      0.75        13
#     class 2       0.86      0.86      0.86         7
#     class 3       0.67      1.00      0.80         4
#     class 4       1.00      0.75      0.86         4
#
# avg / total       0.88      0.87      0.87        61

# %%
dtc = tree.DecisionTreeClassifier(criterion= 'entropy', min_samples_leaf= 1, min_samples_split= 2, splitter= 'random')
dtc.fit(training_set, training_set_labels)
dot_data = tree.export_graphviz(dtc, out_file='dataset2_tree.dot', feature_names=training_set.columns, 
                                filled=True, rounded=True)  
graph = graphviz.Source(dot_data)
from subprocess import check_call
# check_call(['dot','-Tpng','dataset2_tree.dot','-o','dataset2_tree.png'])

# %%
C_range = 10. ** np.arange(-3, 8)
gamma_range = 10. ** np.arange(-5, 4)
param_grid = dict(C = C_range, gamma = gamma_range)
grid_svc = GridSearchCV(estimator=svm_c, param_grid=param_grid)
grid_result_svc = grid_svc.fit(training_set_upsampled, training_set_upsampled_labels)


print("Best: %f using %s" % (grid_result_svc.best_score_, grid_result_svc.best_params_))
means = grid_result_svc.cv_results_['mean_test_score']
stds = grid_result_svc.cv_results_['std_test_score']
params = grid_result_svc.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    
predicted_testing_set_labels = grid_svc.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)
# Out:
# Best: 0.955556 using {'C': 1.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 1.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 1.0, 'gamma': 1.0}
# 0.955556 (0.022662) with: {'C': 1.0, 'gamma': 10.0}
# 0.955556 (0.022662) with: {'C': 1.0, 'gamma': 100.0}
# 0.955556 (0.022662) with: {'C': 1.0, 'gamma': 1000.0}
# 0.955556 (0.022662) with: {'C': 10.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 10.0, 'gamma': 1.0}
# 0.955556 (0.022662) with: {'C': 10.0, 'gamma': 10.0}
# 0.955556 (0.022662) with: {'C': 10.0, 'gamma': 100.0}
# 0.955556 (0.022662) with: {'C': 10.0, 'gamma': 1000.0}
# 0.955556 (0.022662) with: {'C': 100.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 100.0, 'gamma': 1.0}
# 0.955556 (0.022662) with: {'C': 100.0, 'gamma': 10.0}
# 0.955556 (0.022662) with: {'C': 100.0, 'gamma': 100.0}
# 0.955556 (0.022662) with: {'C': 100.0, 'gamma': 1000.0}
# 0.955556 (0.022662) with: {'C': 1000.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 1000.0, 'gamma': 1.0}
# 0.955556 (0.022662) with: {'C': 1000.0, 'gamma': 10.0}
# 0.955556 (0.022662) with: {'C': 1000.0, 'gamma': 100.0}
# 0.955556 (0.022662) with: {'C': 1000.0, 'gamma': 1000.0}
# 0.955556 (0.022662) with: {'C': 10000.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 10000.0, 'gamma': 1.0}
# 0.955556 (0.022662) with: {'C': 10000.0, 'gamma': 10.0}
# 0.955556 (0.022662) with: {'C': 10000.0, 'gamma': 100.0}
# 0.955556 (0.022662) with: {'C': 10000.0, 'gamma': 1000.0}
# 0.955556 (0.022662) with: {'C': 100000.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 100000.0, 'gamma': 1.0}
# 0.955556 (0.022662) with: {'C': 100000.0, 'gamma': 10.0}
# 0.955556 (0.022662) with: {'C': 100000.0, 'gamma': 100.0}
# 0.955556 (0.022662) with: {'C': 100000.0, 'gamma': 1000.0}
# 0.955556 (0.022662) with: {'C': 1000000.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 1000000.0, 'gamma': 1.0}
# 0.955556 (0.022662) with: {'C': 1000000.0, 'gamma': 10.0}
# 0.955556 (0.022662) with: {'C': 1000000.0, 'gamma': 100.0}
# 0.955556 (0.022662) with: {'C': 1000000.0, 'gamma': 1000.0}
# 0.955556 (0.022662) with: {'C': 10000000.0, 'gamma': 0.1}
# 0.955556 (0.022662) with: {'C': 10000000.0, 'gamma': 1.0}
# 0.955556 (0.022662) with: {'C': 10000000.0, 'gamma': 10.0}
# 0.955556 (0.022662) with: {'C': 10000000.0, 'gamma': 100.0}
# 0.955556 (0.022662) with: {'C': 10000000.0, 'gamma': 1000.0}
# 0.936296 (0.005543) with: {'C': 10.0, 'gamma': 0.01}
# 0.936296 (0.005543) with: {'C': 100.0, 'gamma': 0.01}
# 0.936296 (0.005543) with: {'C': 1000.0, 'gamma': 0.01}
# 0.936296 (0.005543) with: {'C': 10000.0, 'gamma': 0.01}
# 0.936296 (0.005543) with: {'C': 100000.0, 'gamma': 0.01}
# 0.936296 (0.005543) with: {'C': 1000000.0, 'gamma': 0.01}
# 0.936296 (0.005543) with: {'C': 10000000.0, 'gamma': 0.01}
# 0.921481 (0.002095) with: {'C': 1.0, 'gamma': 0.01}
# 0.920000 (0.023796) with: {'C': 10000.0, 'gamma': 0.0001}
# 0.914074 (0.023611) with: {'C': 100000.0, 'gamma': 0.0001}
# 0.914074 (0.023611) with: {'C': 1000000.0, 'gamma': 0.0001}
# 0.914074 (0.020635) with: {'C': 10000000.0, 'gamma': 1e-05}
# 0.914074 (0.023611) with: {'C': 10000000.0, 'gamma': 0.0001}
# 0.903704 (0.024162) with: {'C': 1000000.0, 'gamma': 1e-05}
# 0.897778 (0.013084) with: {'C': 1000.0, 'gamma': 0.001}
# 0.897778 (0.013084) with: {'C': 10000.0, 'gamma': 0.001}
# 0.897778 (0.013084) with: {'C': 100000.0, 'gamma': 0.001}
# 0.897778 (0.013084) with: {'C': 1000000.0, 'gamma': 0.001}
# 0.897778 (0.013084) with: {'C': 10000000.0, 'gamma': 0.001}
# 0.891852 (0.018622) with: {'C': 100.0, 'gamma': 0.001}
# 0.875556 (0.003629) with: {'C': 1000.0, 'gamma': 0.0001}
# 0.856296 (0.009132) with: {'C': 10.0, 'gamma': 0.001}
# 0.856296 (0.033718) with: {'C': 100000.0, 'gamma': 1e-05}
# 0.765926 (0.019986) with: {'C': 10000.0, 'gamma': 1e-05}
# 0.760000 (0.020205) with: {'C': 100.0, 'gamma': 0.0001}
# 0.722963 (0.062469) with: {'C': 0.001, 'gamma': 0.01}
# 0.722963 (0.062469) with: {'C': 0.01, 'gamma': 0.01}
# 0.722963 (0.062469) with: {'C': 0.1, 'gamma': 0.01}
# 0.706667 (0.040895) with: {'C': 1.0, 'gamma': 0.001}
# 0.688889 (0.034996) with: {'C': 0.001, 'gamma': 0.1}
# 0.688889 (0.034996) with: {'C': 0.01, 'gamma': 0.1}
# 0.688889 (0.034996) with: {'C': 0.1, 'gamma': 0.1}
# 0.688889 (0.034996) with: {'C': 0.1, 'gamma': 1.0}
# 0.688889 (0.034996) with: {'C': 0.1, 'gamma': 10.0}
# 0.688889 (0.034996) with: {'C': 0.1, 'gamma': 100.0}
# 0.688889 (0.034996) with: {'C': 0.1, 'gamma': 1000.0}
# 0.629630 (0.081171) with: {'C': 0.001, 'gamma': 1.0}
# 0.629630 (0.081171) with: {'C': 0.001, 'gamma': 10.0}
# 0.629630 (0.081171) with: {'C': 0.001, 'gamma': 100.0}
# 0.629630 (0.081171) with: {'C': 0.001, 'gamma': 1000.0}
# 0.629630 (0.081171) with: {'C': 0.01, 'gamma': 1.0}
# 0.629630 (0.081171) with: {'C': 0.01, 'gamma': 10.0}
# 0.629630 (0.081171) with: {'C': 0.01, 'gamma': 100.0}
# 0.629630 (0.081171) with: {'C': 0.01, 'gamma': 1000.0}
# 0.619259 (0.030434) with: {'C': 1000.0, 'gamma': 1e-05}
# 0.561481 (0.040788) with: {'C': 10.0, 'gamma': 0.0001}
# 0.511111 (0.076206) with: {'C': 0.1, 'gamma': 0.001}
# 0.494815 (0.036710) with: {'C': 0.001, 'gamma': 0.001}
# 0.494815 (0.036710) with: {'C': 0.01, 'gamma': 0.001}
# 0.468148 (0.029332) with: {'C': 100.0, 'gamma': 1e-05}
# 0.358519 (0.026252) with: {'C': 10.0, 'gamma': 1e-05}
# 0.357037 (0.007554) with: {'C': 1.0, 'gamma': 0.0001}
# 0.330370 (0.016363) with: {'C': 0.001, 'gamma': 0.0001}
# 0.330370 (0.016363) with: {'C': 0.01, 'gamma': 0.0001}
# 0.321481 (0.029106) with: {'C': 0.1, 'gamma': 0.0001}
# 0.297778 (0.043546) with: {'C': 1.0, 'gamma': 1e-05}
# 0.288889 (0.034617) with: {'C': 0.001, 'gamma': 1e-05}
# 0.288889 (0.034617) with: {'C': 0.01, 'gamma': 1e-05}
# 0.288889 (0.034617) with: {'C': 0.1, 'gamma': 1e-05}

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.82      1.00      0.90        33
#     class 1       1.00      0.69      0.82        13
#     class 2       1.00      0.86      0.92         7
#     class 3       1.00      1.00      1.00         4
#     class 4       1.00      0.50      0.67         4
#
# avg / total       0.91      0.89      0.88        61

# %%
ax = plot.grid_search(grid_svc.grid_scores_, change=('C', 'gamma'))
fig = ax.get_figure()
fig.set_size_inches(18.5, 10.5)
fig.savefig('dataset2_svm.png')
fig.clf()
# Out:
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
n_neighbors = [5, 6, 7, 8, 9, 10]
weights = ["uniform", "distance"]
p = [1, 2, 3, 4]
param_grid = dict(n_neighbors = n_neighbors, weights = weights, p = p)
grid_knn = GridSearchCV(estimator=knn, param_grid=param_grid)
grid_result_knn = grid_knn.fit(training_set_upsampled, training_set_upsampled_labels)


print("Best: %f using %s" % (grid_result_knn.best_score_, grid_result_knn.best_params_))
means = grid_result_knn.cv_results_['mean_test_score']
stds = grid_result_knn.cv_results_['std_test_score']
params = grid_result_knn.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    

predicted_testing_set_labels = grid_knn.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)
# Out:
# Best: 0.871111 using {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.871111 (0.025142) with: {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.869630 (0.024162) with: {'n_neighbors': 6, 'p': 1, 'weights': 'distance'}
# 0.868148 (0.026252) with: {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.868148 (0.024162) with: {'n_neighbors': 8, 'p': 1, 'weights': 'distance'}
# 0.860741 (0.017901) with: {'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.859259 (0.027716) with: {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.859259 (0.023330) with: {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.859259 (0.021874) with: {'n_neighbors': 9, 'p': 4, 'weights': 'distance'}
# 0.857778 (0.023796) with: {'n_neighbors': 8, 'p': 4, 'weights': 'distance'}
# 0.856296 (0.022173) with: {'n_neighbors': 6, 'p': 2, 'weights': 'distance'}
# 0.853333 (0.025402) with: {'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.853333 (0.022662) with: {'n_neighbors': 6, 'p': 3, 'weights': 'distance'}
# 0.853333 (0.019202) with: {'n_neighbors': 8, 'p': 2, 'weights': 'distance'}
# 0.853333 (0.018856) with: {'n_neighbors': 9, 'p': 3, 'weights': 'distance'}
# 0.853333 (0.015818) with: {'n_neighbors': 10, 'p': 4, 'weights': 'distance'}
# 0.851852 (0.024701) with: {'n_neighbors': 7, 'p': 4, 'weights': 'distance'}
# 0.851852 (0.020951) with: {'n_neighbors': 8, 'p': 3, 'weights': 'distance'}
# 0.851852 (0.015108) with: {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.850370 (0.023330) with: {'n_neighbors': 6, 'p': 4, 'weights': 'distance'}
# 0.850370 (0.016761) with: {'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.848889 (0.025402) with: {'n_neighbors': 5, 'p': 4, 'weights': 'distance'}
# 0.848889 (0.025402) with: {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.847407 (0.024162) with: {'n_neighbors': 7, 'p': 3, 'weights': 'distance'}
# 0.847407 (0.017901) with: {'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.706667 (0.065420) with: {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.687407 (0.063514) with: {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.675556 (0.058062) with: {'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.672593 (0.050847) with: {'n_neighbors': 5, 'p': 4, 'weights': 'uniform'}
# 0.650370 (0.036349) with: {'n_neighbors': 6, 'p': 1, 'weights': 'uniform'}
# 0.628148 (0.038802) with: {'n_neighbors': 6, 'p': 2, 'weights': 'uniform'}
# 0.617778 (0.037887) with: {'n_neighbors': 6, 'p': 3, 'weights': 'uniform'}
# 0.616296 (0.030863) with: {'n_neighbors': 6, 'p': 4, 'weights': 'uniform'}
# 0.600000 (0.029031) with: {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.585185 (0.033522) with: {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.585185 (0.026749) with: {'n_neighbors': 8, 'p': 1, 'weights': 'uniform'}
# 0.579259 (0.013739) with: {'n_neighbors': 7, 'p': 4, 'weights': 'uniform'}
# 0.574815 (0.023330) with: {'n_neighbors': 7, 'p': 3, 'weights': 'uniform'}
# 0.560000 (0.037887) with: {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.549630 (0.026749) with: {'n_neighbors': 8, 'p': 2, 'weights': 'uniform'}
# 0.549630 (0.020635) with: {'n_neighbors': 8, 'p': 4, 'weights': 'uniform'}
# 0.549630 (0.042371) with: {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.539259 (0.014666) with: {'n_neighbors': 8, 'p': 3, 'weights': 'uniform'}
# 0.527407 (0.033718) with: {'n_neighbors': 9, 'p': 4, 'weights': 'uniform'}
# 0.521481 (0.032928) with: {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.518519 (0.037067) with: {'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.518519 (0.025745) with: {'n_neighbors': 10, 'p': 4, 'weights': 'uniform'}
# 0.514074 (0.030434) with: {'n_neighbors': 9, 'p': 3, 'weights': 'uniform'}
# 0.512593 (0.029555) with: {'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.91      0.94      0.93        33
#     class 1       0.82      0.69      0.75        13
#     class 2       0.78      1.00      0.88         7
#     class 3       1.00      1.00      1.00         4
#     class 4       0.67      0.50      0.57         4
#
# avg / total       0.87      0.87      0.86        61

# %%
ax = plot.grid_search(grid_knn.grid_scores_, change=('n_neighbors', 'p'), subset={'weights': 'uniform'})
fig = ax.get_figure()
fig.set_size_inches(18.5, 10.5)
fig.savefig('dataset2_knn1.png')
fig.clf()
ax = plot.grid_search(grid_knn.grid_scores_, change=('n_neighbors', 'p'), subset={'weights': 'distance'})
fig = ax.get_figure()
fig.set_size_inches(18.5, 10.5)
fig.savefig('dataset2_knn2.png')
fig.clf()
# Out:
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
nEstimators = [100, 300, 500, 700, 900]
learning_rates = [0.1, 0.3, 0.5, 0.7, 1.0]
param_grid = dict(learning_rate = learning_rates, n_estimators = nEstimators)
grid_b = GridSearchCV(estimator=gbc, param_grid=param_grid)
grid_result_b = grid_b.fit(training_set_upsampled, training_set_upsampled_labels)


print("Best: %f using %s" % (grid_result_b.best_score_, grid_result_b.best_params_))
means = grid_result_b.cv_results_['mean_test_score']
stds = grid_result_b.cv_results_['std_test_score']
params = grid_result_b.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))


predicted_testing_set_labels = grid_b.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc=accuracy_score(testing_set_labels, predicted_testing_set_labels)
# Out:
# Best: 0.931852 using {'learning_rate': 0.7, 'n_estimators': 100}
# 0.931852 (0.004190) with: {'learning_rate': 0.7, 'n_estimators': 100}
# 0.931852 (0.004190) with: {'learning_rate': 0.7, 'n_estimators': 500}
# 0.930370 (0.005543) with: {'learning_rate': 0.7, 'n_estimators': 300}
# 0.928889 (0.003629) with: {'learning_rate': 0.7, 'n_estimators': 700}
# 0.928889 (0.000000) with: {'learning_rate': 0.7, 'n_estimators': 900}
# 0.927407 (0.008381) with: {'learning_rate': 0.5, 'n_estimators': 900}
# 0.925926 (0.009132) with: {'learning_rate': 0.1, 'n_estimators': 100}
# 0.925926 (0.010476) with: {'learning_rate': 0.5, 'n_estimators': 500}
# 0.924444 (0.009601) with: {'learning_rate': 0.3, 'n_estimators': 100}
# 0.924444 (0.003629) with: {'learning_rate': 0.3, 'n_estimators': 300}
# 0.924444 (0.006285) with: {'learning_rate': 0.3, 'n_estimators': 900}
# 0.924444 (0.009601) with: {'learning_rate': 0.5, 'n_estimators': 100}
# 0.924444 (0.009601) with: {'learning_rate': 0.5, 'n_estimators': 700}
# 0.922963 (0.005543) with: {'learning_rate': 0.5, 'n_estimators': 300}
# 0.921481 (0.005543) with: {'learning_rate': 0.3, 'n_estimators': 500}
# 0.921481 (0.002095) with: {'learning_rate': 0.3, 'n_estimators': 700}
# 0.921481 (0.005543) with: {'learning_rate': 1.0, 'n_estimators': 300}
# 0.920000 (0.013084) with: {'learning_rate': 0.1, 'n_estimators': 300}
# 0.920000 (0.003629) with: {'learning_rate': 1.0, 'n_estimators': 700}
# 0.920000 (0.007258) with: {'learning_rate': 1.0, 'n_estimators': 900}
# 0.918519 (0.005543) with: {'learning_rate': 0.1, 'n_estimators': 900}
# 0.918519 (0.005543) with: {'learning_rate': 1.0, 'n_estimators': 100}
# 0.918519 (0.005543) with: {'learning_rate': 1.0, 'n_estimators': 500}
# 0.915556 (0.007258) with: {'learning_rate': 0.1, 'n_estimators': 500}
# 0.915556 (0.007258) with: {'learning_rate': 0.1, 'n_estimators': 700}

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.92      1.00      0.96        33
#     class 1       1.00      0.77      0.87        13
#     class 2       0.75      0.86      0.80         7
#     class 3       0.80      1.00      0.89         4
#     class 4       1.00      0.50      0.67         4
#
# avg / total       0.91      0.90      0.90        61

# %%
ax = plot.grid_search(grid_b.grid_scores_, change=('learning_rate', 'n_estimators'))
fig = ax.get_figure()
fig.set_size_inches(18.5, 10.5)
fig.savefig('dataset2_boosting1.png')
fig.clf()
# Out:
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
alphas = [0.0001, 0.0002, 0.0005, 0.0007, 0.001, 0.002, 0.005, 0.01]
learning_rates = [0.001, 0.002, 0.005, 0.007, 0.01]
hidden_layer_sizes=[(100,), (200,), (300,), (400,), (500,)]
# momentums = [0.9, 0.85, 0.8, 0.75, 0.7]
param_grid = dict(alpha=alphas, learning_rate_init = learning_rates, hidden_layer_sizes = hidden_layer_sizes)
grid_nn = GridSearchCV(estimator=nn, param_grid=param_grid)
grid_result_nn = grid_nn.fit(training_set_upsampled, training_set_upsampled_labels)


print("Best: %f using %s" % (grid_result_nn.best_score_, grid_result_nn.best_params_))
means = grid_result_nn.cv_results_['mean_test_score']
stds = grid_result_nn.cv_results_['std_test_score']
params = grid_result_nn.cv_results_['params']
results = zip(means, stds, params)
for mean, stdev, param in sorted(results, key=lambda x: x[0], reverse=True):
    print("%f (%f) with: %r" % (mean, stdev, param))
    

predicted_testing_set_labels = grid_nn.predict(testing_set)
predicted_testing_set_labels = pd.DataFrame(predicted_testing_set_labels)
testing_set_acc_nn=accuracy_score(testing_set_labels, predicted_testing_set_labels)
# Out:
# Best: 0.503704 using {'alpha': 0.0002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.503704 (0.033718) with: {'alpha': 0.0002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.503704 (0.039973) with: {'alpha': 0.005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.002}
# 0.490370 (0.004190) with: {'alpha': 0.0001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.005}
# 0.485926 (0.029332) with: {'alpha': 0.0002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.001}
# 0.485926 (0.034490) with: {'alpha': 0.01, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.001}
# 0.478519 (0.070398) with: {'alpha': 0.005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.474074 (0.016761) with: {'alpha': 0.0001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.001}
# 0.474074 (0.037244) with: {'alpha': 0.0005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.007}
# 0.465185 (0.065955) with: {'alpha': 0.0007, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.465185 (0.036349) with: {'alpha': 0.0007, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.001}
# 0.462222 (0.044592) with: {'alpha': 0.0007, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.001}
# 0.457778 (0.015818) with: {'alpha': 0.002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.001}
# 0.456296 (0.052629) with: {'alpha': 0.0001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.01}
# 0.456296 (0.039807) with: {'alpha': 0.0007, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.007}
# 0.456296 (0.013739) with: {'alpha': 0.005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.001}
# 0.453333 (0.009601) with: {'alpha': 0.01, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.451852 (0.052126) with: {'alpha': 0.01, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.001}
# 0.450370 (0.032727) with: {'alpha': 0.0005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.002}
# 0.450370 (0.012744) with: {'alpha': 0.01, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.002}
# 0.447407 (0.038461) with: {'alpha': 0.002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.01}
# 0.444444 (0.080082) with: {'alpha': 0.01, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.002}
# 0.444444 (0.028342) with: {'alpha': 0.01, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.002}
# 0.442963 (0.015108) with: {'alpha': 0.001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.005}
# 0.441481 (0.044346) with: {'alpha': 0.001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.001}
# 0.441481 (0.089944) with: {'alpha': 0.002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.007}
# 0.441481 (0.027716) with: {'alpha': 0.005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.001}
# 0.440000 (0.018144) with: {'alpha': 0.005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.005}
# 0.438519 (0.029555) with: {'alpha': 0.0002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.002}
# 0.438519 (0.064949) with: {'alpha': 0.002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.002}
# 0.435556 (0.036289) with: {'alpha': 0.0001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.002}
# 0.434074 (0.025488) with: {'alpha': 0.0001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.434074 (0.061191) with: {'alpha': 0.0007, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.002}
# 0.434074 (0.018265) with: {'alpha': 0.002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.007}
# 0.432593 (0.058999) with: {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.007}
# 0.432593 (0.055551) with: {'alpha': 0.0001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.001}
# 0.432593 (0.058664) with: {'alpha': 0.0005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.002}
# 0.432593 (0.083884) with: {'alpha': 0.0007, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.002}
# 0.432593 (0.020635) with: {'alpha': 0.001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.001}
# 0.432593 (0.024162) with: {'alpha': 0.002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.001}
# 0.429630 (0.066551) with: {'alpha': 0.0005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.005}
# 0.429630 (0.044789) with: {'alpha': 0.001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.001}
# 0.429630 (0.060975) with: {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.002}
# 0.428148 (0.039807) with: {'alpha': 0.005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.002}
# 0.423704 (0.041269) with: {'alpha': 0.0001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.002}
# 0.420741 (0.037244) with: {'alpha': 0.0002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.005}
# 0.420741 (0.054594) with: {'alpha': 0.0005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.001}
# 0.419259 (0.038461) with: {'alpha': 0.0001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.002}
# 0.419259 (0.058213) with: {'alpha': 0.001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.002}
# 0.419259 (0.011086) with: {'alpha': 0.01, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.005}
# 0.419259 (0.020951) with: {'alpha': 0.01, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.007}
# 0.417778 (0.045325) with: {'alpha': 0.0005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.417778 (0.063583) with: {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.005}
# 0.417778 (0.073389) with: {'alpha': 0.001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.007}
# 0.416296 (0.055551) with: {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.01}
# 0.416296 (0.018265) with: {'alpha': 0.005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.01}
# 0.414815 (0.065855) with: {'alpha': 0.0007, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.001}
# 0.414815 (0.027716) with: {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001}
# 0.413333 (0.028342) with: {'alpha': 0.0007, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.002}
# 0.410370 (0.081171) with: {'alpha': 0.0001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.007}
# 0.410370 (0.040137) with: {'alpha': 0.0007, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.005}
# 0.408889 (0.045325) with: {'alpha': 0.0002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.007}
# 0.408889 (0.018856) with: {'alpha': 0.0007, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.002}
# 0.408889 (0.147718) with: {'alpha': 0.0007, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.007}
# 0.407407 (0.084041) with: {'alpha': 0.0002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001}
# 0.407407 (0.053127) with: {'alpha': 0.0005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.01}
# 0.407407 (0.049536) with: {'alpha': 0.001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.002}
# 0.407407 (0.029555) with: {'alpha': 0.002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.005}
# 0.405926 (0.059111) with: {'alpha': 0.0007, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.007}
# 0.405926 (0.079698) with: {'alpha': 0.01, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.01}
# 0.404444 (0.072849) with: {'alpha': 0.001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.01}
# 0.404444 (0.069234) with: {'alpha': 0.01, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.007}
# 0.402963 (0.007554) with: {'alpha': 0.0001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.002}
# 0.402963 (0.018265) with: {'alpha': 0.0005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001}
# 0.402963 (0.095622) with: {'alpha': 0.001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.007}
# 0.401481 (0.071327) with: {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001}
# 0.401481 (0.045082) with: {'alpha': 0.002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.401481 (0.054594) with: {'alpha': 0.005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.007}
# 0.400000 (0.034996) with: {'alpha': 0.01, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.01}
# 0.398519 (0.052879) with: {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.005}
# 0.397037 (0.025745) with: {'alpha': 0.001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.002}
# 0.397037 (0.050064) with: {'alpha': 0.001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.002}
# 0.397037 (0.027477) with: {'alpha': 0.002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.007}
# 0.395556 (0.139038) with: {'alpha': 0.005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.001}
# 0.394074 (0.029106) with: {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.002}
# 0.394074 (0.045373) with: {'alpha': 0.0005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.002}
# 0.394074 (0.112573) with: {'alpha': 0.002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.01}
# 0.392593 (0.021263) with: {'alpha': 0.002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.002}
# 0.392593 (0.136618) with: {'alpha': 0.01, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.007}
# 0.391111 (0.010887) with: {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.01}
# 0.391111 (0.064508) with: {'alpha': 0.0002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.01}
# 0.391111 (0.082432) with: {'alpha': 0.0007, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.002}
# 0.391111 (0.021773) with: {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.007}
# 0.389630 (0.027477) with: {'alpha': 0.0002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.007}
# 0.389630 (0.068309) with: {'alpha': 0.0002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.005}
# 0.389630 (0.047361) with: {'alpha': 0.0007, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.01}
# 0.388148 (0.015108) with: {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.007}
# 0.386667 (0.020205) with: {'alpha': 0.0005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.005}
# 0.386667 (0.034617) with: {'alpha': 0.0005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.005}
# 0.386667 (0.070833) with: {'alpha': 0.0007, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.005}
# 0.386667 (0.025142) with: {'alpha': 0.002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.002}
# 0.385185 (0.032928) with: {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.005}
# 0.385185 (0.108947) with: {'alpha': 0.0007, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001}
# 0.383704 (0.102918) with: {'alpha': 0.0002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.002}
# 0.383704 (0.023046) with: {'alpha': 0.0005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.01}
# 0.383704 (0.050327) with: {'alpha': 0.002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.01}
# 0.382222 (0.067208) with: {'alpha': 0.0002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.005}
# 0.382222 (0.103852) with: {'alpha': 0.0002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.002}
# 0.382222 (0.059959) with: {'alpha': 0.0007, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.005}
# 0.380741 (0.128266) with: {'alpha': 0.0002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.007}
# 0.380741 (0.037067) with: {'alpha': 0.002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.005}
# 0.379259 (0.093392) with: {'alpha': 0.0005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.002}
# 0.379259 (0.014666) with: {'alpha': 0.0005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.001}
# 0.379259 (0.004190) with: {'alpha': 0.005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.002}
# 0.377778 (0.112495) with: {'alpha': 0.0002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.001}
# 0.377778 (0.044592) with: {'alpha': 0.005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.002}
# 0.376296 (0.080520) with: {'alpha': 0.0005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.001}
# 0.376296 (0.126872) with: {'alpha': 0.002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.007}
# 0.374815 (0.120811) with: {'alpha': 0.0007, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.007}
# 0.374815 (0.123666) with: {'alpha': 0.005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.007}
# 0.374815 (0.036349) with: {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.01}
# 0.373333 (0.122579) with: {'alpha': 0.0007, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.01}
# 0.371852 (0.080520) with: {'alpha': 0.01, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.01}
# 0.368889 (0.120301) with: {'alpha': 0.001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.007}
# 0.367407 (0.090673) with: {'alpha': 0.001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.005}
# 0.367407 (0.089209) with: {'alpha': 0.002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.005}
# 0.365926 (0.033718) with: {'alpha': 0.002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.005}
# 0.364444 (0.126178) with: {'alpha': 0.002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.001}
# 0.364444 (0.051192) with: {'alpha': 0.005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.005}
# 0.362963 (0.136762) with: {'alpha': 0.01, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.001}
# 0.361481 (0.081817) with: {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.002}
# 0.361481 (0.074752) with: {'alpha': 0.01, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.002}
# 0.361481 (0.040137) with: {'alpha': 0.01, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.005}
# 0.360000 (0.065420) with: {'alpha': 0.0002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.001}
# 0.358519 (0.017149) with: {'alpha': 0.0001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.001}
# 0.358519 (0.045373) with: {'alpha': 0.0007, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.01}
# 0.358519 (0.032727) with: {'alpha': 0.002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.002}
# 0.358519 (0.068980) with: {'alpha': 0.005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.01}
# 0.358519 (0.031705) with: {'alpha': 0.005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.002}
# 0.357037 (0.061833) with: {'alpha': 0.0002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.002}
# 0.357037 (0.065454) with: {'alpha': 0.0005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.007}
# 0.355556 (0.090939) with: {'alpha': 0.005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001}
# 0.354074 (0.024162) with: {'alpha': 0.001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.007}
# 0.349630 (0.115346) with: {'alpha': 0.001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.01}
# 0.346667 (0.068949) with: {'alpha': 0.0002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.01}
# 0.345185 (0.106687) with: {'alpha': 0.0001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.007}
# 0.343704 (0.119826) with: {'alpha': 0.0005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.007}
# 0.343704 (0.074752) with: {'alpha': 0.0005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.005}
# 0.343704 (0.102918) with: {'alpha': 0.001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.001}
# 0.342222 (0.080247) with: {'alpha': 0.002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.005}
# 0.342222 (0.106913) with: {'alpha': 0.005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.005}
# 0.342222 (0.059739) with: {'alpha': 0.01, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.005}
# 0.340741 (0.094374) with: {'alpha': 0.0005, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.002}
# 0.339259 (0.012744) with: {'alpha': 0.005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.01}
# 0.337778 (0.074987) with: {'alpha': 0.002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001}
# 0.337778 (0.028342) with: {'alpha': 0.005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.005}
# 0.336296 (0.055551) with: {'alpha': 0.0002, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.005}
# 0.333333 (0.098649) with: {'alpha': 0.0002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.005}
# 0.320000 (0.059739) with: {'alpha': 0.002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.002}
# 0.317037 (0.092684) with: {'alpha': 0.0007, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.007}
# 0.317037 (0.126872) with: {'alpha': 0.001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.01}
# 0.315556 (0.134268) with: {'alpha': 0.0002, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.002}
# 0.314074 (0.011086) with: {'alpha': 0.0001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.005}
# 0.312593 (0.089944) with: {'alpha': 0.0001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.005}
# 0.312593 (0.084743) with: {'alpha': 0.0001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.007}
# 0.312593 (0.089062) with: {'alpha': 0.001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.005}
# 0.309630 (0.155040) with: {'alpha': 0.01, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.01}
# 0.308148 (0.025745) with: {'alpha': 0.005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.005}
# 0.306667 (0.095184) with: {'alpha': 0.0001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.01}
# 0.306667 (0.094141) with: {'alpha': 0.0005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.01}
# 0.306667 (0.147718) with: {'alpha': 0.0005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.01}
# 0.305185 (0.124356) with: {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001}
# 0.303704 (0.075541) with: {'alpha': 0.0002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.01}
# 0.297778 (0.116971) with: {'alpha': 0.0007, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.01}
# 0.290370 (0.095346) with: {'alpha': 0.0005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.007}
# 0.287407 (0.111279) with: {'alpha': 0.0005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.01}
# 0.285926 (0.121518) with: {'alpha': 0.0001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.01}
# 0.282963 (0.117327) with: {'alpha': 0.005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.01}
# 0.281481 (0.071142) with: {'alpha': 0.01, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.005}
# 0.280000 (0.056335) with: {'alpha': 0.01, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.007}
# 0.278519 (0.111042) with: {'alpha': 0.0001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.01}
# 0.277037 (0.063514) with: {'alpha': 0.005, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.007}
# 0.274074 (0.043294) with: {'alpha': 0.0002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.007}
# 0.274074 (0.068116) with: {'alpha': 0.002, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.01}
# 0.271111 (0.085336) with: {'alpha': 0.0005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.007}
# 0.271111 (0.052336) with: {'alpha': 0.001, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.005}
# 0.262222 (0.069519) with: {'alpha': 0.005, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.007}
# 0.247407 (0.067044) with: {'alpha': 0.0007, 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.01}
# 0.245926 (0.038118) with: {'alpha': 0.0002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.01}
# 0.240000 (0.056569) with: {'alpha': 0.0001, 'hidden_layer_sizes': (200,), 'learning_rate_init': 0.007}
# 0.240000 (0.036829) with: {'alpha': 0.0007, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.005}
# 0.238519 (0.054473) with: {'alpha': 0.005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.007}
# 0.225185 (0.035617) with: {'alpha': 0.002, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.007}
# 0.225185 (0.035617) with: {'alpha': 0.002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.01}
# 0.214815 (0.020951) with: {'alpha': 0.001, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.01}
# 0.211852 (0.008381) with: {'alpha': 0.0001, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.005}
# 0.205926 (0.008381) with: {'alpha': 0.0007, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.005}
# 0.201481 (0.002095) with: {'alpha': 0.0005, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.005}
# 0.201481 (0.002095) with: {'alpha': 0.005, 'hidden_layer_sizes': (400,), 'learning_rate_init': 0.01}
# 0.200000 (0.000000) with: {'alpha': 0.0002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.007}
# 0.200000 (0.000000) with: {'alpha': 0.0002, 'hidden_layer_sizes': (500,), 'learning_rate_init': 0.01}

# %%
# ax = plot.grid_search(grid_nn.grid_scores_, change=('alpha', 'learning_rate_init'),
#               subset={'hidden_layer_sizes': (300,)})
# fig = ax.get_figure()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('dataset2_NN1.png')
# fig.clf()
ax = plot.grid_search(grid_nn.grid_scores_, change=('alpha', 'hidden_layer_sizes'),
              subset={'learning_rate_init': 0.001})
fig = ax.get_figure()
fig.set_size_inches(18.5, 10.5)
fig.savefig('dataset2_NN2.png')
fig.clf()
# Out:
# /Users/tomhuang/.local/share/virtualenvs/assignment1-2RDWss_u/lib/python3.6/site-packages/sklearn/model_selection/_search.py:762: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
print(classification_report(testing_set_labels, predicted_testing_set_labels, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.84      0.82      0.83        33
#     class 1       0.60      0.46      0.52        13
#     class 2       0.25      0.14      0.18         7
#     class 3       0.11      0.25      0.15         4
#     class 4       0.33      0.50      0.40         4
#
# avg / total       0.64      0.61      0.62        61
